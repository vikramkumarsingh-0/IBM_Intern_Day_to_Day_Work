# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
df = sns.load_dataset('tips')

# %%
df.head()
x = df['total_bill']
y = df['tip']

# %%
sns.scatterplot(x='total_bill',y='tip', data=df, hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import matplotlib.pyplot as plt
sns.relplot(
data=df,
x = 'total_bill', y = 'tip',
hue = 'time',
size = 'size',
sizes=(10, 100),
palette = 'Accent_r'
)

plt.xlabel('Total Bill in USD $')
plt.ylabel('Yips to the service in usd $')
plt.title('New York Restaurent Data')
# Out:
# Text(0.5, 1.0, 'New York Restaurent Data')

# %%
sns.lineplot(data=df, x='total_bill', y='size', hue='sex', style='sex', markers=True, palette='Blues_d', dashes=True)

plt.xlabel('Total Bill in USD $')
plt.ylabel('Yips to the service in usd $')
plt.title('New York Restaurent Data')
# Out:
# Text(0.5, 1.0, 'New York Restaurent Data')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='size', y='total_bill', data=df, ci=None)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17520\1881561272.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='size', y='total_bill', data=df, ci=None)
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.barplot(x='size', y='total_bill', data=df, palette = 'Accent', hue='sex')
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.histplot(x='size', data=df, kde=True, bins=5, hue='sex', palette='Blues_r')
# Out:
# <Axes: xlabel='size', ylabel='Count'>

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(x='size', data=df)

# %%
sns.kdeplot(x='size', data=df, hue='smoker', fill=True, linewidth = 2.5)
# Out:
# <Axes: xlabel='size', ylabel='Density'>

# %%
sns.boxplot(x = 'day', y = 'tip', data = df, hue = "smoker", palette = "Accent", linewidth = 2, fliersize = 10)

# median = 5'6", range: 5'2" - 5'9"
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x = 'day', y = 'tip', data= df)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
x = df['total_bill']
y = df['tip']

# %%
data = {
    "bill": df["total_bill"],
    "tip" : df['tip'],
    "size": df['size']
}

# %%
import pandas as pd
df1 = pd.DataFrame(data)

# %%
c = df1.corr()

# %%
c
# Out:
#           bill       tip      size
# bill  1.000000  0.675734  0.598315
# tip   0.675734  1.000000  0.489299
# size  0.598315  0.489299  1.000000

# %%
sns.heatmap(c,annot = True, linecolor = 'red', linewidth = 5, cbar = False, xticklabels = False, yticklabels = False)
# vmin = 0, vmax = 2, cmap = 'tab20', center = 0,
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.figure(figsize =(6, 6))
sns.pairplot(data =df, hue="smoker")
plt.show()

# %%
df = sns.load_dataset("iris")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df, hue = "species", diag_kind = 'kde', palette = "Accent")

# %%
sns.scatterplot(x = 'sepal_length', y = 'petal_width', data = df)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
sns.jointplot(x = 'sepal_length', y = 'petal_width', data = df)

# %%
sns.FacetGrid(df, col='sepal_length')

# %%
df = sns.load_dataset('tips')

# %%
a = sns.FacetGrid(df, col='smoker', row='day')
a.map(sns.scatterplot, 'total_bill', 'tip')

# %%
a.map(sns.scatterplot, 'total_bill', 'tip')

# %%
tips = sns.load_dataset("tips")
sns.FacetGrid(tips)

# %%
sns.FacetGrid(tips, col="time", row="sex")

# %%
g = sns.FacetGrid(tips, col="time", row="sex", hue="size")
g.map(sns.scatterplot, "total_bill", "tip")
