# %% [markdown]
# Data Analysis

# %%
import pandas as abc
import matplotlib.pyplot as plt

# %%
df = abc.read_csv("america.csv")

# %%
df
# Out:
#              336 W Army Trail Rd.  1
# 0       Bloomingdale IL 60108 USA  0
# 1           2710 Laporte Ave #100  1
# 2         Valparaiso IN 46383 USA  0
# 3                   531 S Rand Rd  1
# 4        Lake Zurich IL 60047 USA  0
# ..                            ... ..
# 161           Naples FL 34108 USA  1
# 162                  5020 95th St  0
# 163         Oak Lawn IL 60453 USA  1
# 164        6645 Orchard Lake Road  0
# 165  West Bloomfield MI 48322 USA  1
#
# [166 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   336 W Army Trail Rd.  166 non-null    object
#  1   1                     166 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.7+ KB

# %%
df.head()
# Out:
#         336 W Army Trail Rd.  1
# 0  Bloomingdale IL 60108 USA  0
# 1      2710 Laporte Ave #100  1
# 2    Valparaiso IN 46383 USA  0
# 3              531 S Rand Rd  1
# 4   Lake Zurich IL 60047 USA  0

# %%
df.tail()
# Out:
#              336 W Army Trail Rd.  1
# 161           Naples FL 34108 USA  1
# 162                  5020 95th St  0
# 163         Oak Lawn IL 60453 USA  1
# 164        6645 Orchard Lake Road  0
# 165  West Bloomfield MI 48322 USA  1

# %%
df.describe()
# Out:
#                 1
# count  166.000000
# mean     0.500000
# std      0.501513
# min      0.000000
# 25%      0.000000
# 50%      0.500000
# 75%      1.000000
# max      1.000000

# %%
y = df['336 W Army Trail Rd.']

# %%
plt.plot(y)
plt.show()
